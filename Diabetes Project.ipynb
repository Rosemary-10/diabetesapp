# %%
# !pip install plotly

# %%
import pandas as pd

# %%
pd.read_csv('diabetes.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %%
x=df.drop(columns=['Outcome'])
y=df['Outcome']

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import numpy as np

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size=0.2, random_state=10)

# %%
df.shape, x_train.shape, x_test.shape
# Out:
# ((768, 9), (614, 8), (154, 8))

# %%
diabetes = svm.SVC(kernel='linear')  #rbf, #sigmoid, #poly

# %%
diabetes.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
xtrain_prediction = diabetes.predict(x_train)
training_data_accuracy = accuracy_score(xtrain_prediction, y_train)

# %%
print('Accuracy Score', training_data_accuracy)
# Out:
# Accuracy Score 0.7752442996742671

# %%
xtest_prediction = diabetes.predict(x_test)
testing_data_accuracy = accuracy_score(xtest_prediction, y_test)

# %%
print('Accuracy Score', testing_data_accuracy)
# Out:
# Accuracy Score 0.7597402597402597

# %%
df.to_csv('Cleaned Diabetes Dataset.csv') #to export to csv

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
##the input_data holds your data values
input_data = (6,148,72,35,0,33.6,0.627,50)

# changing the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshaping the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardizing the input data
#std_data = scaler.transform(input_data_reshaped)
#print(std_data)

prediction = diabetes.predict(input_data_reshaped)
#print(prediction)

if (prediction[0] == 0):
  print('Congratulations! You are not susceptible to diabetes')

else:
  print('Unfortunately, you are susceptible to diabetes')
# Out:
# Unfortunately, you are susceptible to diabetes

# %%
6,148,72,35,0,33.6,0.627,50
1,85,66,29,0,26.6,0.351,31
# Out:
# (1, 85, 66, 29, 0, 26.6, 0.351, 31)

# %%
##the input_data holds your data values
input_data = (1,85,66,29,0,26.6,0.351,31)

# changing the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshaping the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardizing the input data
#std_data = scaler.transform(input_data_reshaped)
#print(std_data)

prediction = diabetes.predict(input_data_reshaped)
#print(prediction)

if (prediction[0] == 0):
  print('Congratulations! You are not susceptible to diabetes.')

else:
  print('Unfortunately, you are susceptible to diabetes.')
# Out:
# Congratulations! You are not susceptible to diabetes.

# %%
import pickle

# %%
# Converting our file to a pickle file
filename = 'diabetes_classifier.sav'

# %%
# Writing our pickle file
pickle.dump(diabetes, open('diabetes_classifier', 'wb'))

# %%
loaded_model = pickle.load(open('diabetes_classifier', 'rb'))

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
# to check the error before deploying to streamlit, launch anaconda prompt and input the names of the folders
# cd desktop, cd python, cd ml, cd mlprojects then streamlit run app.py

# %%
# to get the requirements.txt, on github, go to add file, then create new file
